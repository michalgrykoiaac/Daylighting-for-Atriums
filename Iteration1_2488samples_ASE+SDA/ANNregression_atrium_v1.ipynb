# %% [markdown]
# #Numerical regression

# %% [markdown]
# in this example we will use Keras to predict wages based on various professional and demographic factors.

# %%
# Import standard Libraries
import pandas as pd
import seaborn as sns
import altair as alt
import tensorflow as tf
import matplotlib.pyplot as plt



sns.set(rc={'figure.figsize':(10,10)})
print("imports ok")
# Out:
# imports ok

# %% [markdown]
# ##Load Data

# %%
#connect google drive to this colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load data file
data = pd.read_csv('/content/gdrive/MyDrive/ColabNotebooks/DataEncoding/atrium_SDA+ASE_regression_analysis/Iteration1_2488samples_ASE+SDA/atrium_SDA+ASE_v1_2488_samples.csv', delimiter= " ")
pd.options.display.max_columns = None
data = data.dropna(axis=0)
#print(data)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2488 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   typicalGlazingRatio  2488 non-null   float64
#  1   typicalWindowWidth   2488 non-null   int64
#  2   groundGlazingRatio   2488 non-null   float64
#  3   groundWindowWidth    2488 non-null   int64
#  4   buildingDepth        2488 non-null   int64
#  5   balconyWidth         2488 non-null   int64
#  6   siteWidth            2488 non-null   int64
#  7   siteLength           2488 non-null   int64
#  8   floorDepth           2488 non-null   float64
#  9   groundHeight         2488 non-null   int64
#  10  typicalHeight        2488 non-null   int64
#  11  levelNo              2488 non-null   int64
#  12  skylightArea         2488 non-null   float64
#  13  netTotalArea         2488 non-null   int64
#  14  netGroundArea        2488 non-null   int64
#  15  buildingHeight       2488 non-null   int64
#  16  atriumVolume         2488 non-null   int64
#  17  roofArea             2488 non-null   int64
#  18  groundSDA            2488 non-null   float64
#  19  firstSDA             2488 non-null   float64
#  20  groundASE            2488 non-null   float64
#  21  firstASE             2488 non-null   float64
# dtypes: float64(8), int64(14)
# memory usage: 447.1 KB
# None

# %%
data.shape
# Out:
# (2488, 17)

# %%
#data.drop(columns=["roofArea","buildingHeight"], inplace=True)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2488 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   typicalGlazingRatio  2488 non-null   float64
#  1   typicalWindowWidth   2488 non-null   int64
#  2   groundGlazingRatio   2488 non-null   float64
#  3   groundWindowWidth    2488 non-null   int64
#  4   buildingDepth        2488 non-null   int64
#  5   balconyWidth         2488 non-null   int64
#  6   siteWidth            2488 non-null   int64
#  7   siteLength           2488 non-null   int64
#  8   floorDepth           2488 non-null   float64
#  9   groundHeight         2488 non-null   int64
#  10  typicalHeight        2488 non-null   int64
#  11  levelNo              2488 non-null   int64
#  12  skylightArea         2488 non-null   float64
#  13  netTotalArea         2488 non-null   int64
#  14  netGroundArea        2488 non-null   int64
#  15  buildingHeight       2488 non-null   int64
#  16  atriumVolume         2488 non-null   int64
#  17  roofArea             2488 non-null   int64
#  18  groundSDA            2488 non-null   float64
#  19  firstSDA             2488 non-null   float64
#  20  groundASE            2488 non-null   float64
#  21  firstASE             2488 non-null   float64
# dtypes: float64(8), int64(14)
# memory usage: 447.1 KB
# None

# %%
for colname, col in data.iteritems():
  print(colname, "min_val", col.min(), "max_val", col.max())
# Out:
# typicalGlazingRatio min_val 0.7 max_val 0.9
# typicalWindowWidth min_val 2 max_val 4
# groundGlazingRatio min_val 0.7 max_val 0.9
# groundWindowWidth min_val 2 max_val 4
# buildingDepth min_val 15 max_val 33
# balconyWidth min_val 1 max_val 6
# siteWidth min_val 40 max_val 80
# siteLength min_val 40 max_val 80
# floorDepth min_val 0.3 max_val 1.0
# groundHeight min_val 3 max_val 6
# typicalHeight min_val 3 max_val 3
# levelNo min_val 1 max_val 10
# skylightArea min_val 100.0 max_val 2352.0
# netTotalArea min_val 3472 max_val 115100
# netGroundArea min_val 1600 max_val 6400
# buildingHeight min_val 6 max_val 36
# atriumVolume min_val 720 max_val 78336
# roofArea min_val 1500 max_val 5952
# groundSDA min_val 24.1 max_val 100.0
# firstSDA min_val 21.4 max_val 99.4
# groundASE min_val 0.5 max_val 54.6
# firstASE min_val 0.0 max_val 20.8

# %% [markdown]
# ##Prepare Data

# %% [markdown]
# **NORMALIZE INPUTS**

# %%
#same code as last time

#declare features
#X = data.iloc[:,1:-1]
X = data[["typicalWindowWidth", "groundGlazingRatio", "groundWindowWidth", "typicalGlazingRatio", "buildingDepth", "balconyWidth", "siteWidth", "siteLength", "groundHeight", "typicalHeight", "levelNo", "skylightArea", "netTotalArea"]]   

# Load and instantiate a StandardSclaer 
from sklearn.preprocessing import StandardScaler
scalerX = StandardScaler()

# Apply the scaler to our X-features
X_scaled = scalerX.fit_transform(X)

print(X_scaled.shape)
# Out:
# (2488, 13)

# %%
#declare regression target
#y = data.loc[:,"wage_per_hour"].to_numpy()
y = data.loc[:, ["groundSDA", "firstSDA", "groundASE", "firstASE"]].to_numpy()

#y = y.reshape(-1, 1)

from sklearn.preprocessing import MinMaxScaler
scalerY = MinMaxScaler()


#In this case it makes sense to use MinMax scaling because the wage seems like a relative range
# Apply the scaler to our Y-features
y_scaled = scalerY.fit_transform(y)

print(y_scaled.shape)
print(y_scaled)
# Out:
# (2488, 4)
# [[0.36627141 0.32051282 0.15896488 0.05769231]
#  [1.         0.23461538 0.49168207 0.25480769]
#  [0.61791831 0.76666667 0.34195933 0.79326923]
#  ...
#  [0.7826087  0.26025641 0.29205176 0.19230769]
#  [1.         0.44871795 0.40480591 0.29326923]
#  [0.59025033 0.27435897 0.23475046 0.31730769]]

# %% [markdown]
# **SPLIT INTO TRAIN AND TEST**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 21)

# %%
#visualize our data
#we can see that scikitlearn doesnt care if it is a dataframe or a numpy array, because they all function on the same way 
print("TRAIN", "input", X_train.shape, "output", y_train.shape)
print("TEST", "input", X_test.shape, "output", y_test.shape)
print(X_test)
print(y_test)
# Out:
# TRAIN input (1990, 13) output (1990, 4)
# TEST input (498, 13) output (498, 4)
# [[-1.21050067e+00  1.39639361e+00  1.24953709e+00 ... -8.63272524e-01
#    3.47751845e-01 -5.98756440e-01]
#  [-1.21050067e+00  1.39639361e+00  1.24953709e+00 ...  8.71360039e-01
#    2.73487919e-02  1.79531035e+00]
#  [ 5.37565903e-03 -2.51396559e-02 -1.22763286e+00 ... -5.16346011e-01
#    1.37016601e-03  2.88607973e-01]
#  ...
#  [-1.21050067e+00 -2.51396559e-02 -1.22763286e+00 ... -1.21019904e+00
#    1.15597576e+00 -9.78460581e-01]
#  [ 1.22125199e+00 -1.44667293e+00 -1.22763286e+00 ...  5.24433527e-01
#   -1.05220744e+00  2.10670196e-01]
#  [-1.21050067e+00 -2.51396559e-02 -1.22763286e+00 ... -1.55712555e+00
#   -3.65217111e-01 -1.41300982e+00]]
# [[0.26086957 0.16025641 0.24768946 0.29807692]
#  [0.73781291 0.09615385 0.33271719 0.14423077]
#  [0.68511199 0.12307692 0.24029575 0.25480769]
#  ...
#  [1.         0.54102564 0.44362292 0.21634615]
#  [0.79710145 0.19230769 0.1663586  0.29326923]
#  [1.         0.92179487 0.48983364 0.65865385]]

# %% [markdown]
# #Build model

# %% [markdown]
# From the cheatSheet
# Regression between 0 and 1>>
#       activation = relu for hidden layers / sigmoid for final layer
#       loss = mean squared error
#       optimizer = adam
#       input from data, is 8 columns
#       output is 1 value prediction

# %%
# Instantiate a sequential model
#tf.seed(5)
#model.save()
model = tf.keras.models.Sequential()
n_cols = X_scaled.shape[1]  

# Add 2 dense layers of 50 and 32 neurons each
model.add(tf.keras.layers.Dense(32, input_shape=(n_cols,), activation='relu'))
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(4, activation='relu'))
  
# Add a dense layer with 1 value output
#model.add(tf.keras.layers.Dense(1, activation= "linear"))
  
# Compile your model 
model.compile(optimizer = "adam", loss = "mean_squared_error")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 32)                448
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 8)                 136
#
#  dense_10 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 1,148
# Trainable params: 1,148
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Train model

# %%
# Fit your model to the training data for 200 epochs
#we assign this to history variable so we can plot the training data
history = model.fit(X_train,y_train,epochs=200, validation_split=0.2)
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 7ms/step - loss: 0.1355 - val_loss: 0.0630
# Epoch 2/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0376 - val_loss: 0.0275
# Epoch 3/200
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 4/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 5/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 6/200
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0151
# Epoch 7/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 8/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0134
# Epoch 9/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0127
# Epoch 10/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0112 - val_loss: 0.0121
# Epoch 11/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0118
# Epoch 12/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0113
# Epoch 13/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0108
# Epoch 14/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0105
# Epoch 15/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 16/200
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0099
# Epoch 17/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0097
# Epoch 18/200
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0094
# Epoch 19/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0092
# Epoch 20/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 21/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0088
# Epoch 22/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 23/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 24/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 25/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0083
# Epoch 26/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0083
# Epoch 27/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0081
# Epoch 28/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0080
# Epoch 29/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 30/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0080
# Epoch 31/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 32/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 33/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0078
# Epoch 34/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0078
# Epoch 35/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0076
# Epoch 36/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0076
# Epoch 37/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0076
# Epoch 38/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0075
# Epoch 39/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 40/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 41/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0075
# Epoch 42/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0074
# Epoch 43/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 44/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 45/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 46/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0073
# Epoch 47/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0073
# Epoch 48/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0074
# Epoch 49/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0073
# Epoch 50/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0075
# Epoch 51/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0074
# Epoch 52/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0073
# Epoch 53/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0072
# Epoch 54/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0072
# Epoch 55/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 56/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0072
# Epoch 57/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 58/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 59/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 60/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0074
# Epoch 61/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 62/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 63/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0072
# Epoch 64/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0073
# Epoch 65/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0073
# Epoch 66/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 67/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 68/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 69/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 70/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0072
# Epoch 71/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 72/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 73/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 74/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0074
# Epoch 75/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0072
# Epoch 76/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0075
# Epoch 77/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 78/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0073
# Epoch 79/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0072
# Epoch 80/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0074
# Epoch 81/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0073
# Epoch 82/200
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0073
# Epoch 83/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0073
# Epoch 84/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0074
# Epoch 85/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0073
# Epoch 86/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0072
# Epoch 87/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0074
# Epoch 88/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0075
# Epoch 89/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0074
# Epoch 90/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0073
# Epoch 91/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0073
# Epoch 92/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 93/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 94/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 95/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0074
# Epoch 96/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0074
# Epoch 97/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 98/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0075
# Epoch 99/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0074
# Epoch 100/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0074
# Epoch 101/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0075
# Epoch 102/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 103/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0076
# Epoch 104/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 105/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 106/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0075
# Epoch 107/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0074
# Epoch 108/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0076
# Epoch 109/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0077
# Epoch 110/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0075
# Epoch 111/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 112/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0075
# Epoch 113/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0077
# Epoch 114/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 115/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 116/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0077
# Epoch 117/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 118/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 119/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 120/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0076
# Epoch 121/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 122/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0081
# Epoch 123/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0078
# Epoch 124/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 125/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0078
# Epoch 126/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0078
# Epoch 127/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0078
# Epoch 128/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0078
# Epoch 129/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0078
# Epoch 130/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0079
# Epoch 131/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 132/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0081
# Epoch 133/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0081
# Epoch 134/200
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0078
# Epoch 135/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0076
# Epoch 136/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0080
# Epoch 137/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0080
# Epoch 138/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0081
# Epoch 139/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 140/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 141/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 142/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0083
# Epoch 143/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0081
# Epoch 144/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 145/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0081
# Epoch 146/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0080
# Epoch 147/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0082
# Epoch 148/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0078
# Epoch 149/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 150/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0081
# Epoch 151/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0079
# Epoch 152/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 153/200
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0080
# Epoch 154/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0082
# Epoch 155/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 156/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0086
# Epoch 157/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0080
# Epoch 158/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 159/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 160/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 161/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 162/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 163/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0084
# Epoch 164/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 165/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 166/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0080
# Epoch 167/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0080
# Epoch 168/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 169/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 170/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0082
# Epoch 171/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0080
# Epoch 172/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 173/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0079
# Epoch 174/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 175/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0081
# Epoch 176/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 177/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 178/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0081
# Epoch 179/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0081
# Epoch 180/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0085
# Epoch 181/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0085
# Epoch 182/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0081
# Epoch 183/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 184/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 185/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 186/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 187/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 188/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 189/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 190/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 191/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 192/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0082
# Epoch 193/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 194/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 195/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0084
# Epoch 196/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 197/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0084
# Epoch 198/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0086
# Epoch 199/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0085
# Epoch 200/200
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0086

# %%
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss function')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# #Evaluate model on test data

# %%
# Evaluate your model accuracy on the test data
loss_test = model.evaluate(X_test,y_test)

# Print accuracy
print('mse_test:', loss_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0078
# mse_test: 0.0078011308796703815

# %% [markdown]
# #Plot error

# %%
def plot_comparison(x_val, pred, truth, xlab, ylab):
  fig, ax1 = plt.subplots()
  ax1.plot(x_val, truth, color = "red", label = "truth",linestyle='None', marker = "o", markersize = 5)
  ax1.plot(x_val, pred, color = "blue", label = "pred",linestyle='None', marker = "o", markersize = 4, alpha = 0.5)

  ax1.set_xlabel(xlab)
  ax1.set_ylabel(ylab)
  ax1.legend()
  fig.set_figheight(10)
  fig.set_figwidth(20)
  plt.title('Prediction Comparison')
  plt.show()

# %%
y_pred = scalerY.inverse_transform(model.predict(X_test))
y_truth = scalerY.inverse_transform(y_test)

plt.scatter(y_truth,y_pred)

# %%
y_pred = scalerY.inverse_transform(model.predict(X_test))
y_truth = scalerY.inverse_transform(y_test)
plt.scatter(y_truth,y_truth, c='red')
plt.scatter(y_pred,y_pred, c='blue')

# %%
#GROUND DAYLIGHT PREDICTIONS
y_pred_01 = y_pred[:,0]
print(y_pred_01.shape)
# Out:
# (498,)

# %%
print(y_pred.shape)
# Out:
# (498, 4)

# %%
#GROUND DAYLIGHT TRUTH
y_truth_01 = y_truth[:,0]
print(y_truth_01.shape)
# Out:
# (498,)

# %%
skylightArea = (scalerX.inverse_transform(X_test)[:,11])

# %%
#PLOT SkylightArea 
plot_comparison(skylightArea, y_pred_01, y_truth_01, "skylightArea", "sDA")
#plot_comparison(build_area, y_pred_01, y_truth_01, "build_area", "Radiation_Total")
#plot_comparison(max_depth, y_pred_01, y_truth_01, "buil_depth", "Radiation_Total")

# %%
error = y_pred - y_truth
plt.hist(error, bins=10)
plt.xlabel('Prediction Error')
_ = plt.ylabel('Count')
